# %% [markdown]
# <a href="https://colab.research.google.com/github/feitosaerica/Aula-19-08-2026/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 0 // na linguagem python para Divisão inteira
x = 3
y = 2
resultado = x//y
print (resultado)
# Out:
# 1

# %%
# 0 // calculo de media dois valores
valor1 - float(input("digite o primeiro valor: "))
valor2 - float(input("digite o segundo valor: "))

# calcula a media de dois valores
media - (valor1 + valor2) / 2

# exibir o resultado

print("A média entre {valor1} e {valor2} é {media:.2}
# Out:
#   File "/tmp/ipykernel_1823/833167260.py", line 10
#     print("A média entre {valor1} e {valor2} é {media:.2}
#           ^
# SyntaxError: unterminated string literal (detected at line 10)
