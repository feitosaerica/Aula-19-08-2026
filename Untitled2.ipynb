# %% [markdown]
# <a href="https://colab.research.google.com/github/feitosaerica/Aula-19-08-2026/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Estrura condicional - Resolução 1

num = int(input("Digite valor inteiro:"))
resto = num%2
print(resto)
if resto==0:
  print("É PAR")
else:
  print("É ÍMPAR")
# Out:
# Digite valor inteiro:5
# 1
# É ÍMPAR

# %%
# Resolução 2

num = int(input("Digite valor inteiro:"))
resto = num%2
print(resto)
if resto==0:
  print("É PAR")
else:
  print("É ÍMPAR")

# %%
#Solicitar ao usuário que insira um número

numero = int(input("Digite um número inteiro: "))

# Verifica se o número é par ou ímpar
if numero % 2 == 0:
  print(f"O número {numero} é par")
else:
  print(f"O múmero {numero} é ímpar")
# Out:
# Digite um número inteiro: 7
# O múmero 7 é ímpar

# %%
#Cálculo de medidas camiseta

comprimento = float(input("Digite o comprimento da camiseta em centímetros: "))
largura = float(input("Digite a largura da camiseta em centímetros: "))

if comprimento <= 60 and largura <= 45:
  tamanho = "pp"
elif comprimento <= 65 and largura <= 48:
  tamanho = "p"
elif comprimento <= 70 and largura <= 51:
  tamanho = "m"
elif comprimento <= 75 and largura <= 54:
  tamanho = "g"
elif comprimento <= 80 and largura <= 57:
  tamanho = "gg"
else:
  tamanho = "xgg"

print(f"O tamanho da camiseta é {tamanho}.")
# Out:
# Digite o comprimento da camiseta em centímetros: 89
# Digite a largura da camiseta em centímetros: 41
# O tamanho da camiseta é xgg.
